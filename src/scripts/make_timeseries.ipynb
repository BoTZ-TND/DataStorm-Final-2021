# %%
import numpy as np 
import pandas as pd 
import pandas_profiling

# %%
train_df = pd.read_csv('../../data/feature/part2.csv')
train_df.head()
print(train_df.isnull().sum())
print(train_df.info())
# Out:
#    Unnamed: 0  main_holder_occupation_cd  policy_term policy_payment_mode  \
# 0       79686                      226.0          144                   M
# 1      375697                      175.0          240                   M
# 2      592003                      226.0          180                   Y
# 3      123460                      450.0          144                   H
# 4      170518                      450.0          144                   Y
#
#   policy_status commencement_dt next_due_dt main_holder_gender  \
# 0       INFORCE      2018-12-28  2019/01/28                  M
# 1       INFORCE      2018-12-29  2019/01/29                  M
# 2       INFORCE      2018-12-28  2019/12/28                  M
# 3       INFORCE      2018-12-31  2019/06/30                  F
# 4       INFORCE      2018-12-28  2019/12/28                  F
#
#   main_holder_dob  main_holder_entry_age  ... policy_code  policy_snapshot  \
# ...

# %%
train_df.columns
# Out:
# Index(['Unnamed: 0', 'main_holder_occupation_cd', 'policy_term',
#        'policy_payment_mode', 'policy_status', 'commencement_dt',
#        'next_due_dt', 'main_holder_gender', 'main_holder_dob',
#        'main_holder_entry_age', 'main_holder_smoker_flag',
#        'total_sum_assuared', 'premium_value', 'child1_dob', 'child2_dob',
#        'payment_method', 'policy_snapshot_as_on', 'client_code', 'agent_code',
#        'product_code', 'policy_code', 'policy_snapshot', 'unique',
#        'total_rider_prem', 'total_rider_sum_assuared', 'children_count',
#        'month_rank', 'current_age', 'completed_duration', 'completed_ratio'],
#       dtype='object')
