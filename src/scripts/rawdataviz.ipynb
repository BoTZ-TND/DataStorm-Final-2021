# %%
import pandas as pd 
import sweetviz as sv 
import warnings

# %%
agent_df = pd.read_csv('../../data/data/datastorm_agent_data.csv')
policy_df = pd.read_csv('../../data/data/datastorm_policy_data.csv')
# Out:
# c:\Users\Tharindu\Desktop\Professional development\Competitions\Datastorm2021\datastorm_2021final\DataStorm-Final-2021\venv\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (46,47) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
policy_df.iloc[:,46]
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 631417    NaN
# 631418    NaN
# 631419    NaN
# 631420    NaN
# 631421    NaN
# Name: child5_dob, Length: 631422, dtype: object

# %%
agent_col_report = sv.analyze(agent_df)
agent_col_report.show_html()
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
policy_col_report = sv.analyze(policy_df)
policy_col_report.show_html()
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:02 -> (00:00 left)Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
