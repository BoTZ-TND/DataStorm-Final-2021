# %%
import numpy as np
import pandas as pd
from causality.analysis.dataframe import CausalDataFrame

# %%
train_df = pd.read_csv('../../../data/feature/final3.csv').sample(frac=1)

# %%
train_df.head()
# Out:
#       policy_term  policy_payment_mode  policy_status  \
# 2881          240            -0.020976       0.335611
# 1815          360            -0.020976      -0.198882
# 684           360             0.048856      -0.198882
# 4113           60             1.031354      -0.198882
# 3007          240            -0.020976      -0.198882
#
#       main_holder_smoker_flag  main_holder_gender  total_sum_assuared  \
# 2881                -0.210090            0.006204            350000.0
# 1815                 0.018666            0.006204            275000.0
# 684                  0.018666           -0.011252            500000.0
# 4113                 0.018666           -0.011252           2100000.0
# 3007                 0.018666            0.006204            225000.0
#
#       premium_value  payment_method  client_code  product_code  month_rank  \
# 2881        18984.0       -0.106502        21260             1           5
# ...

# %%
X = CausalDataFrame(data=train_df.to_numpy())
X.zplot(x='month_rank', y='is_cross_sell', z={'completed_ratio': 'c'}, kind='line', model_type='kernel')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-3b5e01a929b6> in <module>
#       1 X = CausalDataFrame(data=train_df.to_numpy())
# ----> 2 X.zplot(x='month_rank', y='is_cross_sell', z={'completed_ratio': 'c'}, kind='line', model_type='kernel')
#
# f:\JetBrain Project Files\Pycharm\DataStorm-Final-2021\venv\lib\site-packages\causality\analysis\dataframe.py in zplot(self, *args, **kwargs)
#      53         if kwargs.get('z', []):
#      54             if kwargs.get('kind') == 'line':
# ---> 55                 return self._line_zplot(*args, **kwargs)
#      56             if kwargs.get('kind') == 'bar' or kwargs.get('kind') == 'mean':
#      57                 return self._bootstrapped_mean_zplot(*args, **kwargs)
#
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.factorplot(x ='children_count', y ='is_cross_sell', 
               hue = 'product_code', data = train_df)
# Out:
# f:\JetBrain Project Files\Pycharm\DataStorm-Final-2021\venv\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
